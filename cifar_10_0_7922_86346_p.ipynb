# %% [markdown]
# <a href="https://colab.research.google.com/github/haddriax/CIFAR-10_classifier/blob/main/cifar_10_0_7922_86346_p.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf

from tensorflow import keras
from keras import layers, models

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()
(x_val, y_val) = (x_train[-10000:], y_train[-10000:])
(x_train, y_train) = (x_train[:-10000], y_train[:-10000])

assert x_train.shape == (40000, 32, 32, 3)
assert x_val.shape == (10000, 32, 32, 3)
assert x_test.shape == (10000, 32, 32, 3)
assert y_train.shape == (40000, 1)
assert y_val.shape == (10000, 1)
assert y_test.shape == (10000, 1)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step

# %%
model = models.Sequential([
    layers.Input(shape=(32, 32, 3)),

    layers.Conv2D(32, (3, 3), activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.Conv2D(32, (3, 3), activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),

    layers.Conv2D(32, (3, 3), activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.Conv2D(32, (3, 3), activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),


    layers.Conv2D(32, (3, 3), activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.Conv2D(32, (3, 3), activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),

    layers.Flatten(),

    layers.Dense(32, activation='relu'),
    layers.Dropout(0.2),

    layers.Dense(128, activation='relu'),
    layers.Dropout(0.2),

    layers.Dense(128, activation='relu'),
    layers.Dropout(0.2),

    # Output layer
    layers.Dense(10, activation='softmax')
])

# %%
best_model = None
best_accuracy = 0.0
monitor = 'val_accuracy'

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 32, 32, 32)          │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 32, 32, 32)          │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 32, 32, 32)          │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 32, 32, 32)          │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 16, 16, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 16, 16, 32)          │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 16, 16, 32)          │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 16, 16, 32)          │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 16, 16, 32)          │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 8, 8, 32)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 8, 8, 32)            │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_4                │ (None, 8, 8, 32)            │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 8, 8, 32)            │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_5                │ (None, 8, 8, 32)            │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 4, 4, 32)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 32)                  │          16,416 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 128)                 │           4,224 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 128)                 │          16,512 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 10)                  │           1,290 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 86,346 (337.29 KB)
#  Trainable params: 85,962 (335.79 KB)
#  Non-trainable params: 384 (1.50 KB)

# %%
epochs = 200

cp_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='saved_cnn.weights.h5',
    monitor=monitor,
    save_best_only=True,
    save_weights_only=True,
    verbose=1)

early_exit_callback = tf.keras.callbacks.EarlyStopping(
    monitor=monitor,
    patience=8,
    restore_best_weights=True,
    verbose=1)

lr_scheduler =  tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.2,
    patience=4,
    min_lr=1e-7)

history = model.fit(x_train,
                    y_train,
                    epochs=epochs,
                    validation_data=(x_test, y_test),
                    callbacks=[cp_callback, early_exit_callback, lr_scheduler]
                    )
# Out:
# Epoch 1/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.3090 - loss: 1.8458
# Epoch 1: val_accuracy improved from -inf to 0.50910, saving model to saved_cnn.weights.h5
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 267s 199ms/step - accuracy: 0.3090 - loss: 1.8456 - val_accuracy: 0.5091 - val_loss: 1.4005 - learning_rate: 0.0010
# Epoch 2/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.5468 - loss: 1.2656
# Epoch 2: val_accuracy improved from 0.50910 to 0.59560, saving model to saved_cnn.weights.h5
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 232s 175ms/step - accuracy: 0.5468 - loss: 1.2655 - val_accuracy: 0.5956 - val_loss: 1.1990 - learning_rate: 0.0010
# Epoch 3/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.6229 - loss: 1.0660
# Epoch 3: val_accuracy improved from 0.59560 to 0.63460, saving model to saved_cnn.weights.h5
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 263s 176ms/step - accuracy: 0.6229 - loss: 1.0660 - val_accuracy: 0.6346 - val_loss: 1.0686 - learning_rate: 0.0010
# Epoch 4/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.6613 - loss: 0.9756
# Epoch 4: val_accuracy improved from 0.63460 to 0.65920, saving model to saved_cnn.weights.h5
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 255s 171ms/step - accuracy: 0.6613 - loss: 0.9756 - val_accuracy: 0.6592 - val_loss: 0.9889 - learning_rate: 0.0010
# Epoch 5/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.6935 - loss: 0.8915
# Epoch 5: val_accuracy improved from 0.65920 to 0.66250, saving model to saved_cnn.weights.h5
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 221s 177ms/step - accuracy: 0.6935 - loss: 0.8914 - val_accuracy: 0.6625 - val_loss: 0.9898 - learning_rate: 0.0010
# Epoch 6/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.7180 - loss: 0.8238
# Epoch 6: val_accuracy improved from 0.66250 to 0.71150, saving model to saved_cnn.weights.h5
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 256s 172ms/step - accuracy: 0.7180 - loss: 0.8238 - val_accuracy: 0.7115 - val_loss: 0.8458 - learning_rate: 0.0010
# Epoch 7/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.7406 - loss: 0.7655
# Epoch 7: val_accuracy did not improve from 0.71150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 219s 175ms/step - accuracy: 0.7406 - loss: 0.7656 - val_accuracy: 0.6982 - val_loss: 0.8998 - learning_rate: 0.0010
# Epoch 8/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.7520 - loss: 0.7162
# Epoch 8: val_accuracy did not improve from 0.71150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 213s 170ms/step - accuracy: 0.7520 - loss: 0.7162 - val_accuracy: 0.6917 - val_loss: 0.8956 - learning_rate: 0.0010
# Epoch 9/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.7653 - loss: 0.6852
# Epoch 9: val_accuracy improved from 0.71150 to 0.72710, saving model to saved_cnn.weights.h5
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 273s 179ms/step - accuracy: 0.7653 - loss: 0.6853 - val_accuracy: 0.7271 - val_loss: 0.7990 - learning_rate: 0.0010
# Epoch 10/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.7810 - loss: 0.6396
# Epoch 10: val_accuracy improved from 0.72710 to 0.73800, saving model to saved_cnn.weights.h5
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 255s 173ms/step - accuracy: 0.7810 - loss: 0.6396 - val_accuracy: 0.7380 - val_loss: 0.7867 - learning_rate: 0.0010
# Epoch 11/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.7882 - loss: 0.6282
# Epoch 11: val_accuracy improved from 0.73800 to 0.75720, saving model to saved_cnn.weights.h5
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 218s 174ms/step - accuracy: 0.7882 - loss: 0.6282 - val_accuracy: 0.7572 - val_loss: 0.7323 - learning_rate: 0.0010
# Epoch 12/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.8015 - loss: 0.5914
# Epoch 12: val_accuracy did not improve from 0.75720
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 260s 173ms/step - accuracy: 0.8015 - loss: 0.5914 - val_accuracy: 0.7057 - val_loss: 0.8726 - learning_rate: 0.0010
# Epoch 13/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.8103 - loss: 0.5637
# Epoch 13: val_accuracy did not improve from 0.75720
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 216s 172ms/step - accuracy: 0.8103 - loss: 0.5638 - val_accuracy: 0.7489 - val_loss: 0.7531 - learning_rate: 0.0010
# Epoch 14/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.8137 - loss: 0.5515
# Epoch 14: val_accuracy did not improve from 0.75720
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 217s 174ms/step - accuracy: 0.8137 - loss: 0.5515 - val_accuracy: 0.7498 - val_loss: 0.7545 - learning_rate: 0.0010
# Epoch 15/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.8219 - loss: 0.5321
# Epoch 15: val_accuracy did not improve from 0.75720
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 268s 178ms/step - accuracy: 0.8219 - loss: 0.5321 - val_accuracy: 0.7523 - val_loss: 0.7358 - learning_rate: 0.0010
# Epoch 16/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.8490 - loss: 0.4512
# Epoch 16: val_accuracy improved from 0.75720 to 0.78260, saving model to saved_cnn.weights.h5
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 261s 178ms/step - accuracy: 0.8490 - loss: 0.4512 - val_accuracy: 0.7826 - val_loss: 0.6730 - learning_rate: 2.0000e-04
# Epoch 17/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.8653 - loss: 0.3944
# Epoch 17: val_accuracy did not improve from 0.78260
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 260s 176ms/step - accuracy: 0.8653 - loss: 0.3944 - val_accuracy: 0.7809 - val_loss: 0.6817 - learning_rate: 2.0000e-04
# Epoch 18/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.8738 - loss: 0.3669
# Epoch 18: val_accuracy improved from 0.78260 to 0.78310, saving model to saved_cnn.weights.h5
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 267s 180ms/step - accuracy: 0.8738 - loss: 0.3669 - val_accuracy: 0.7831 - val_loss: 0.6819 - learning_rate: 2.0000e-04
# Epoch 19/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.8760 - loss: 0.3576
# Epoch 19: val_accuracy did not improve from 0.78310
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 266s 183ms/step - accuracy: 0.8760 - loss: 0.3576 - val_accuracy: 0.7771 - val_loss: 0.7174 - learning_rate: 2.0000e-04
# Epoch 20/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.8863 - loss: 0.3359
# Epoch 20: val_accuracy did not improve from 0.78310
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 252s 176ms/step - accuracy: 0.8863 - loss: 0.3359 - val_accuracy: 0.7810 - val_loss: 0.7192 - learning_rate: 2.0000e-04
# Epoch 21/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.8915 - loss: 0.3209
# Epoch 21: val_accuracy did not improve from 0.78310
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 259s 174ms/step - accuracy: 0.8915 - loss: 0.3209 - val_accuracy: 0.7831 - val_loss: 0.7154 - learning_rate: 4.0000e-05
# Epoch 22/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.8960 - loss: 0.3041
# Epoch 22: val_accuracy did not improve from 0.78310
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 263s 174ms/step - accuracy: 0.8960 - loss: 0.3041 - val_accuracy: 0.7794 - val_loss: 0.7209 - learning_rate: 4.0000e-05
# Epoch 23/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.8970 - loss: 0.3029
# Epoch 23: val_accuracy did not improve from 0.78310
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 260s 173ms/step - accuracy: 0.8970 - loss: 0.3029 - val_accuracy: 0.7816 - val_loss: 0.7262 - learning_rate: 4.0000e-05
# Epoch 24/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.9007 - loss: 0.2921
# Epoch 24: val_accuracy did not improve from 0.78310
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 270s 179ms/step - accuracy: 0.9007 - loss: 0.2921 - val_accuracy: 0.7810 - val_loss: 0.7354 - learning_rate: 4.0000e-05
# Epoch 25/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.9027 - loss: 0.2888
# Epoch 25: val_accuracy did not improve from 0.78310
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 261s 178ms/step - accuracy: 0.9027 - loss: 0.2888 - val_accuracy: 0.7803 - val_loss: 0.7361 - learning_rate: 8.0000e-06
# Epoch 26/200
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.9058 - loss: 0.2780
# Epoch 26: val_accuracy did not improve from 0.78310
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 256s 173ms/step - accuracy: 0.9058 - loss: 0.2780 - val_accuracy: 0.7805 - val_loss: 0.7394 - learning_rate: 8.0000e-06
# Epoch 26: early stopping
# Restoring model weights from the end of the best epoch: 18.

# %%
loss, accuracy = model.evaluate(x_test, y_test)
print("Loss: ", loss)
print("Accuracy: ", accuracy)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 13s 42ms/step - accuracy: 0.7821 - loss: 0.6911
# Loss:  0.6818547248840332
# Accuracy:  0.7831000089645386

# %%
raw_prediction = model.predict(x_test)

y_pred = np.argmax(raw_prediction, axis=1)

y_true = np.concatenate([y for x, y in zip(x_test, y_test)], axis=0)

import seaborn as sns

class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

confusion_mtx = tf.math.confusion_matrix(y_true, y_pred)
plt.figure(figsize=(5, 4))
sns.heatmap(confusion_mtx, xticklabels=class_names, yticklabels=class_names,
            annot=True, fmt='g')

plt.xlabel('Prediction')
plt.ylabel('True label')
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 13s 42ms/step

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(10, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='upper left')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.grid()
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.yscale('log')
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.grid()
plt.show()

# %%
base_model = model.load_weights('saved_cnn.weights.h5')
loss,accuracy = model.evaluate(x_test, y_test)
print("Loss: ", loss)
print("Accuracy: ", accuracy)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 14s 43ms/step - accuracy: 0.7821 - loss: 0.6911
# Loss:  0.6818547248840332
# Accuracy:  0.7831000089645386

# %%
model.trainable = True
print("Number of layers in the base model: ", len(model.layers))

fine_tune_at = 16

for layer in model.layers[:fine_tune_at]:
  layer.trainable = False
# Out:
# Number of layers in the base model:  23

# %%
base_learning_rate = 0.001
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=base_learning_rate/100),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(),
    metrics=['accuracy'])

# %%
initial_epochs = 50
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath='saved_tl.weights.h5',
                                                 monitor='val_loss',
                                                 save_best_only=True,
                                                 save_weights_only=True,
                                                 verbose=1)

history = model.fit(x_train, y_train,
                    epochs=initial_epochs,
                    validation_data=(x_val, y_val), # Use validation data here
                    callbacks=[cp_callback]
                    )
# Out:
# Epoch 1/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.8928 - loss: 0.3122
# Epoch 1: val_loss improved from inf to 0.65323, saving model to saved_tl.weights.h5
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 82s 63ms/step - accuracy: 0.8928 - loss: 0.3122 - val_accuracy: 0.7902 - val_loss: 0.6532
# Epoch 2/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8920 - loss: 0.3177
# Epoch 2: val_loss did not improve from 0.65323
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 84s 65ms/step - accuracy: 0.8920 - loss: 0.3177 - val_accuracy: 0.7915 - val_loss: 0.6556
# Epoch 3/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8951 - loss: 0.3130
# Epoch 3: val_loss did not improve from 0.65323
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 68s 54ms/step - accuracy: 0.8951 - loss: 0.3130 - val_accuracy: 0.7910 - val_loss: 0.6581
# Epoch 4/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8955 - loss: 0.3095
# Epoch 4: val_loss did not improve from 0.65323
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 77s 62ms/step - accuracy: 0.8955 - loss: 0.3095 - val_accuracy: 0.7917 - val_loss: 0.6605
# Epoch 5/50
# 1249/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8976 - loss: 0.3017
# Epoch 5: val_loss did not improve from 0.65323
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 68s 54ms/step - accuracy: 0.8976 - loss: 0.3017 - val_accuracy: 0.7921 - val_loss: 0.6627
# Epoch 6/50
# 1249/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8943 - loss: 0.3101
# Epoch 6: val_loss did not improve from 0.65323
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 76s 61ms/step - accuracy: 0.8943 - loss: 0.3101 - val_accuracy: 0.7917 - val_loss: 0.6644
# Epoch 7/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8923 - loss: 0.3133
# Epoch 7: val_loss did not improve from 0.65323
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 82s 61ms/step - accuracy: 0.8923 - loss: 0.3133 - val_accuracy: 0.7925 - val_loss: 0.6655
# Epoch 8/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8943 - loss: 0.3106
# Epoch 8: val_loss did not improve from 0.65323
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━
50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9024 - loss: 0.2873
# Epoch 41: val_loss did not improve from 0.65323
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 74s 54ms/step - accuracy: 0.9024 - loss: 0.2873 - val_accuracy: 0.7921 - val_loss: 0.6886
# Epoch 42/50
# 1249/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9022 - loss: 0.2863
# Epoch 42: val_loss did not improve from 0.65323
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 82s 54ms/step - accuracy: 0.9022 - loss: 0.2863 - val_accuracy: 0.7928 - val_loss: 0.6896
# Epoch 43/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9001 - loss: 0.2960
# Epoch 43: val_loss did not improve from 0.65323
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 91s 61ms/step - accuracy: 0.9001 - loss: 0.2960 - val_accuracy: 0.7924 - val_loss: 0.6888
# Epoch 44/50
# 1249/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9026 - loss: 0.2873
# Epoch 44: val_loss did not improve from 0.65323
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 74s 54ms/step - accuracy: 0.9026 - loss: 0.2873 - val_accuracy: 0.7923 - val_loss: 0.6891
# Epoch 45/50
# 1249/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9050 - loss: 0.2817
# Epoch 45: val_loss did not improve from 0.65323
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 82s 54ms/step - accuracy: 0.9050 - loss: 0.2817 - val_accuracy: 0.7921 - val_loss: 0.6902
# Epoch 46/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9015 - loss: 0.2925
# Epoch 46: val_loss did not improve from 0.65323
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 82s 54ms/step - accuracy: 0.9015 - loss: 0.2925 - val_accuracy: 0.7925 - val_loss: 0.6906
# Epoch 47/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9021 - loss: 0.2865
# Epoch 47: val_loss did not improve from 0.65323
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 91s 61ms/step - accuracy: 0.9021 - loss: 0.2865 - val_accuracy: 0.7925 - val_loss: 0.6915
# Epoch 48/50
# 1249/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8988 - loss: 0.2921
# Epoch 48: val_loss did not improve from 0.65323
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 81s 60ms/step - accuracy: 0.8988 - loss: 0.2921 - val_accuracy: 0.7925 - val_loss: 0.6916
# Epoch 49/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9006 - loss: 0.2900
# Epoch 49: val_loss did not improve from 0.65323
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 67s 54ms/step - accuracy: 0.9006 - loss: 0.2900 - val_accuracy: 0.7919 - val_loss: 0.6925
# Epoch 50/50
# 1249/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9036 - loss: 0.2876
# Epoch 50: val_loss did not improve from 0.65323
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 82s 54ms/step - accuracy: 0.9036 - loss: 0.2876 - val_accuracy: 0.7923 - val_loss: 0.6924

# %%
plt.figure(figsize=(10, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.plot([initial_epochs-1,initial_epochs-1],
          plt.ylim(), label='Start Fine Tuning')
plt.legend(loc='lower right')
plt.grid()
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.yscale('log')
plt.plot([initial_epochs-1,initial_epochs-1],
         plt.ylim(), label='Start Fine Tuning')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.grid()
plt.show()

# %%
raw_prediction = model.predict(x_test)

y_pred = np.argmax(raw_prediction, axis=1)

y_true = np.concatenate([y for x, y in zip(x_test, y_test)], axis=0)

class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

confusion_mtx = tf.math.confusion_matrix(y_true, y_pred)
plt.figure(figsize=(5, 4))
sns.heatmap(confusion_mtx, xticklabels=class_names, yticklabels=class_names,
            annot=True, fmt='g')

plt.xlabel('Prediction')
plt.ylabel('True label')
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 13s 42ms/step

# %%
loss, accuracy = model.evaluate(x_test, y_test)
print("Test Loss: ", loss)
print("Test Accuracy: ", accuracy)

loss, accuracy = model.evaluate(x_val, y_val)
print("Vali Loss: ", loss)
print("Vali Accuracy: ", accuracy)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 13s 42ms/step - accuracy: 0.7827 - loss: 0.7470
# Test Loss:  0.7344285845756531
# Test Accuracy:  0.7827000021934509
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 13s 42ms/step - accuracy: 0.7823 - loss: 0.7253
# Vali Loss:  0.6924455761909485
# Vali Accuracy:  0.7922999858856201

# %%
plt.figure(figsize=(10, 10))
for i in range(25):
    plt.subplot(5, 5, i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x_test[i])
    plt.xlabel(class_names[y_pred[i]])
plt.show()
